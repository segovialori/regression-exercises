# %% [markdown]
# # Explore Zillow

# %% [markdown]
# ### Imports

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import env

from sklearn.model_selection import train_test_split

import sklearn.preprocessing

# %%
# connection function for accessing mysql 
def get_connection(db, user=env.user, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
def split_data(df, stratify_by=""):
    '''
    take in a DataFrame and return train, validate, and test DataFrames.
    return train, validate, test DataFrames.
    '''
    train_validate, test = train_test_split(df, test_size=.2, random_state=123)
    train, validate = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123)
    return train, validate, test

# %%
# Acquire

query = """
SELECT * 
FROM properties_2017
JOIN predictions_2017 using(parcelid)
WHERE transactiondate between "2017-05-01" and "2017-06-30"
and unitcnt = 1;
"""

df = pd.read_sql(query, get_connection('zillow'))
df.head()
# Out:
#    parcelid       id  airconditioningtypeid architecturalstyletypeid  \
# 0  11289917  2061546                    1.0                     None
# 1  11705026  1834372                    NaN                     None
# 2  11389003  2121349                    NaN                     None
# 3  11967869  2093710                    NaN                     None
# 4  12035176  1288537                    NaN                     None
#
#   basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0         None          2.0         3.0                  NaN
# 1         None          1.0         2.0                  NaN
# 2         None          2.0         3.0                  NaN
# 3         None          1.0         2.0                  NaN
# 4         None          1.0         1.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ... taxvaluedollarcnt  \
# 0                    6.0                2.0  ...          136104.0
# 1                    6.0                1.0  ...           35606.0
# 2                    6.0                2.0  ...          614000.0
# 3                    5.0                1.0  ...          274237.0
# 4                   11.0                1.0  ...          245906.0
#
#   assessmentyear  landtaxvaluedollarcnt  taxamount taxdelinquencyflag  \
# 0         2016.0                27214.0    2319.90                  Y
# 1         2016.0                23624.0     543.69               None
# 2         2016.0               449000.0    7673.19               None
# 3         2016.0               191821.0    3267.47               None
# 4         2016.0               146810.0    2926.19               None
#
#    taxdelinquencyyear censustractandblock    id  logerror transactiondate
# 0                15.0        6.037901e+13  1248 -0.362001      2017-06-23
# 1                 NaN        6.037232e+13  1772 -0.146056      2017-06-30
# 2                 NaN        6.037703e+13  3273 -0.325393      2017-06-01
# 3                 NaN        6.037185e+13  3429 -0.005566      2017-06-29
# 4                 NaN        6.037189e+13  5444 -0.114435      2017-05-24
#
# [5 rows x 62 columns]

# %%
# Some prep
df = df.rename(columns={"bedroomcnt": "bedrooms", "bathroomcnt": "bathrooms", "calculatedfinishedsquarefeet": "square_feet", "taxamount": "taxes", "taxvaluedollarcnt": "tax_value"})

# %%
features = [
    "parcelid",
    "bedrooms",
    "bathrooms",
    "square_feet",
    "tax_value"
]

df = df[features]
df = df.set_index("parcelid")

# Let's drop the nulls
df = df.dropna()

# %%
train, validate, test = split_data(df, stratify_by="tax_value")

# %%
train.head()

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### 1. Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.

# %%
# .corr() is linear correlation coefficient
train.corr()

# %%
sns.scatterplot(x="bedrooms", y="bathrooms", data=train)

# %%
def plot_variable_pairs(df):
    sns.pairplot(train, kind="reg")

# %%
plot_variable_pairs(train)

# %%
df.hist(grid=False, figsize=(16,12), color='lightslategrey')

# %% [markdown]
# ### 2. Write a function named months_to_years that accepts your telco churn dataframe and returns a dataframe with a new feature tenure_years, in complete years as a customer.

# %%
df2 = pd.read_sql(query, get_connection('zillow'))

# %%
df2 = df2.rename(columns={"bedroomcnt": "bedrooms", "bathroomcnt": "bathrooms", "calculatedfinishedsquarefeet": "square_feet", "taxamount": "taxes", "taxvaluedollarcnt": "tax_value"})

# %%
df2.head()
# Out:
#    parcelid       id  airconditioningtypeid architecturalstyletypeid  \
# 0  11289917  2061546                    1.0                     None
# 1  11705026  1834372                    NaN                     None
# 2  11389003  2121349                    NaN                     None
# 3  11967869  2093710                    NaN                     None
# 4  12035176  1288537                    NaN                     None
#
#   basementsqft  bathrooms  bedrooms  buildingclasstypeid  \
# 0         None        2.0       3.0                  NaN
# 1         None        1.0       2.0                  NaN
# 2         None        2.0       3.0                  NaN
# 3         None        1.0       2.0                  NaN
# 4         None        1.0       1.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ... tax_value assessmentyear  \
# 0                    6.0                2.0  ...  136104.0         2016.0
# 1                    6.0                1.0  ...   35606.0         2016.0
# 2                    6.0                2.0  ...  614000.0         2016.0
# 3                    5.0                1.0  ...  274237.0         2016.0
# 4                   11.0                1.0  ...  245906.0         2016.0
#
#    landtaxvaluedollarcnt    taxes taxdelinquencyflag  taxdelinquencyyear  \
# 0                27214.0  2319.90                  Y                15.0
# 1                23624.0   543.69               None                 NaN
# 2               449000.0  7673.19               None                 NaN
# 3               191821.0  3267.47               None                 NaN
# 4               146810.0  2926.19               None                 NaN
#
#   censustractandblock    id  logerror transactiondate
# 0        6.037901e+13  1248 -0.362001      2017-06-23
# 1        6.037232e+13  1772 -0.146056      2017-06-30
# 2        6.037703e+13  3273 -0.325393      2017-06-01
# 3        6.037185e+13  3429 -0.005566      2017-06-29
# 4        6.037189e+13  5444 -0.114435      2017-05-24
#
# [5 rows x 62 columns]

# %%
features = [
    "parcelid",
    "bedrooms",
    "bathrooms",
    "square_feet",
    "tax_value",
    "yearbuilt"
]

df2 = df2[features]
df2 = df2.set_index("parcelid")


# Let's drop the nulls
df2 = df2.dropna()

# %%
train, validate, test = split_data(df2, stratify_by="tax_value")

# %%
def house_age(df):
    df['home_age'] = df['yearbuilt']

# %% [markdown]
# ### 3. Write a function named plot_categorical_and_continuous_vars that accepts your dataframe and the name of the columns that hold the continuous and categorical features and outputs 3 different plots for visualizing a categorical variable and a continuous variable.

# %%
categorical_vars = []
quantitative_vars = ['bedrooms', 'bathrooms', 'square_feet', 'tax_value']


def plot_categorical_and_continuous_vars(df):

# %% [markdown]
# ### 4. Save the functions you have written to create visualizations in a file named explore.py. Rewrite your notebook code so that you are using the functions imported from this file.

# %% [markdown]
# ### 5. Explore your dataset with any other visualizations you think will be helpful.

# %% [markdown]
# ### 6. In a seperate notebook, use the functions you have developed in this exercise with the mall customers dataset.
